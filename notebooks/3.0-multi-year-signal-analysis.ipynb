# %%
import pandas as pd
from collections import Counter
from tqdm.auto import tqdm
import itertools

# Import our custom modules
from src.config import config, PROJECT_ROOT
# Add the new function to the import list
from src.features.build_features import get_embedding_model, find_representative_ngrams, normalize_keywords
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# Initialize tqdm for pandas operations
tqdm.pandas(desc="Processing Documents")

# %%
# Load the processed computer vision dataset
processed_data_path = PROJECT_ROOT / config.data.processed_path
df = pd.read_parquet(processed_data_path)
print(f"Loaded {len(df)} records from {processed_data_path}")

# Load the sentence-transformer model
embedding_model = get_embedding_model()
# Out:
# Loaded 8269 records from C:\Users\lib9\weak-signals-new\data\processed\cv_arxiv_data_2010-2022.parquet

# %%
# Time-slice the data by year
df['year'] = df['published']
yearly_chunks = {year: group for year, group in df.groupby('year')}
print(f"Sliced data into {len(yearly_chunks)} yearly chunks from {df['year'].min()} to {df['year'].max()}.")

# This dictionary will store the final, normalized keywords for each year
yearly_final_keywords = {}

for year, chunk_df in sorted(yearly_chunks.items()):
    print(f"\n--- Processing {len(chunk_df)} documents for year {year} ---")
    
    list_of_keyword_lists = chunk_df['summary'].progress_apply(
        lambda doc: find_representative_ngrams(doc, embedding_model)
    )
    
    all_keywords_for_year = list(itertools.chain.from_iterable(list_of_keyword_lists))
    keyword_counts = Counter(all_keywords_for_year)
    top_300 = {kw for kw, count in keyword_counts.most_common(300)}
    
    cleaned_keywords = {
        kw for kw in top_300 
        if kw not in ENGLISH_STOP_WORDS and len(kw) > 1 and not kw.isdigit()
    }
    
    # Add the new normalization step here
    normalized_keywords = normalize_keywords(cleaned_keywords)
    
    yearly_final_keywords[year] = normalized_keywords
    print(f"Stored {len(normalized_keywords)} normalized keywords for {year}.")
# Out:
# Sliced data into 13 yearly chunks from 2010 to 2022.
#
# --- Processing 25 documents for year 2010 ---
# Processing Documents:   0%|          | 0/25 [00:00<?, ?it/s]
# Stored 190 normalized keywords for 2010.
#
# --- Processing 20 documents for year 2011 ---
# Processing Documents:   0%|          | 0/20 [00:00<?, ?it/s]
# Stored 149 normalized keywords for 2011.
#
# --- Processing 63 documents for year 2012 ---
# Processing Documents:   0%|          | 0/63 [00:00<?, ?it/s]
# Stored 226 normalized keywords for 2012.
#
# --- Processing 104 documents for year 2013 ---
# Processing Documents:   0%|          | 0/104 [00:00<?, ?it/s]
# Stored 216 normalized keywords for 2013.
#
# --- Processing 129 documents for year 2014 ---
# Processing Documents:   0%|          | 0/129 [00:00<?, ?it/s]
# Stored 226 normalized keywords for 2014.
#
# --- Processing 229 documents for year 2015 ---
# Processing Documents:   0%|          | 0/229 [00:00<?, ?it/s]
# Stored 236 normalized keywords for 2015.
#
# --- Processing 406 documents for year 2016 ---
# Processing Documents:   0%|          | 0/406 [00:00<?, ?it/s]
# Stored 232 normalized keywords for 2016.
#
# --- Processing 559 documents for year 2017 ---
# Processing Documents:   0%|          | 0/559 [00:00<?, ?it/s]
# Stored 226 normalized keywords for 2017.
#
# --- Processing 817 documents for year 2018 ---
# Processing Documents:   0%|          | 0/817 [00:00<?, ?it/s]
# Stored 213 normalized keywords for 2018.
#
# --- Processing 1035 documents for year 2019 ---
# Processing Documents:   0%|          | 0/1035 [00:00<?, ?it/s]
# Stored 216 normalized keywords for 2019.
#
# --- Processing 1341 documents for year 2020 ---
# Processing Documents:   0%|          | 0/1341 [00:00<?, ?it/s]
# Stored 216 normalized keywords for 2020.
#
# --- Processing 1710 documents for year 2021 ---
# Processing Documents:   0%|          | 0/1710 [00:00<?, ?it/s]
# Stored 210 normalized keywords for 2021.
#
# --- Processing 1831 documents for year 2022 ---
# Processing Documents:   0%|          | 0/1831 [00:00<?, ?it/s]
# Stored 215 normalized keywords for 2022.

# %%
# Loop through the dictionary to display the keywords for each year

for year, keywords in sorted(yearly_final_keywords.items()):
    # Convert the set to a sorted list for consistent display
    sorted_keywords = sorted(list(keywords))
    
    print(f"\n--- Keywords for {year} ({len(sorted_keywords)} total) ---")
    # Print a sample of up to 25 keywords for the year
    print(sorted_keywords[:300])
# Out:
# --- Keywords for 2010 (190 total) ---
# ['3d model natural', 'accurately detecting pedestrians', 'alignment point sets', 'alternative online boosting', 'approach point detection', 'approximate spectral analysis', 'asymmetric boosting methods', 'automatic video segmentation', 'boosting algorithms improve', 'boosting like adaboost', 'bridge computer vision', 'bright mag stars', 'caenorhabditis elegans elegans', 'calibration multi camera', 'camera positions orientations', 'cameras global coordinate', 'cascade boosting framework', 'catalog real stars', 'centroid locations rigid', 'centroids coherently', 'centroids representing point', 'classic nn classification', 'classification graphical modeling', 'classification rely deforming', 'classifiers learned unn', 'coherent point drift', 'complexity image registration', 'computational understanding appearance', 'computer human vision', 'computer vision empirical', 'computer vision natural', 'conditional random fields', 'conventional boosting like', 'convex functions', 'coordinate data stereo', 'coordinate value camera', 'correspondences vertices considered', 'data subsampling landmark', 'databases natural images', 'deformations surface corresponding', 'denoising deconvolution tomographic', 'depth computation techniques', 'depth maps 3d', 'depth object camera', 'depth object photographed', 'detecting pedestrians images', 'differences sparse reconstruction', 'dimension reduction emphasizing', 'dimensional data provide', 'dimensional video data', 'discriminants small deformations', 'distance fuzzy sets', 'distance rank invariants', 'domains hausdorff distance', 'elegans elegans worms', 'elegans worms grown', 'empirical science visual', 'eqnarray min_ norm', 'estimation depth scene', 'existing online boosting', 'experiments using elegans', 'face detection suggest', 'formulate graph matching', 'formulated graph matching', 'formulation graph matching', 'functions submodular functions', 'graph matching correspondences', 'graph matching problem', 'halos bright stars', 'hausdorff distance encoding', 'hausdorff distance sets', 'high dimensional data', 'human vision abilities', 'image categorization', 'image real depth', 'image registration generalized', 'imaging bayesian experimental', 'improve nn classification', 'inria pedestrian dataset', 'interdependency detector descriptor', 'invariants persistent homology', 'learned offline detector', 'living computer vision', 'low rank matrices', 'low rank representation', 'ltp pedestrian detection', 'mag stars sensitive', 'manifold gradient descent', 'matching correspondences vertices', 'matrix noisy observations', 'medial representation shapes', 'method structured prediction', 'minimization problems gaining', 'model natural scenes', 'neighbors nn classification', 'networks set functions', 'new boosting algorithms', 'noisy observations subset', 'nonlinear dimension reduction', 'norm approximation learn', 'norm minimization problems', 'nuclear norm approximation', 'nuclear norm minimization', 'offline object detectors', 'online boosting algorithms', 'online boosting detectors', 'online greedy sparse', 'optimize landmark selection', 'orientation cameras elegant', 'overdensities faint stars', 'overwhelmingly outliers photometric', 'parameter estimation crfs', 'passive depth computation', 'pedestrian dataset dense', 'pedestrian detection standard', 'persistent homology groups', 'persistent homology respect', 'pixel depth image', 'pixel depth object', 'plane stereo vision', 'point based image', 'point detection common', 'point detection starting', 'point set registration', 'point sets rigid', 'points recover transformation', 'position orientation cameras', 'posterior distribution sparse', 'posteriors high resolution', 'prediction crfs seen', 'proposed boosting algorithms', 'prototypes weak classifiers', 'rank matrix noisy', 'rank representation lrr', 'reconstructing low rank', 'reconstruction approximate bayesian', 'reconstruction methods random', 'recovering 3d geometry', 'reformulate computer visi ...
#
# --- Keywords for 2011 (149 total) ---
# ['3d motion tracking', 'abstractions generalization gives', 'acquiring gesture artificial', 'algorithm minimum cut', 'algorithm searches', 'algorithm searching', 'application computer vision', 'articulated object detection', 'attribute preserving trained', 'bag features bof', 'based shape retrieval', 'camera require estimations', 'card image processing', 'cards identified process', 'classification task distractor', 'compression achieved discovering', 'compression philosophy justify', 'continuous max flow', 'continuous maximum flow', 'convergence fast linearized', 'cut problem primarily', 'data compression view', 'decompositions multiscale multi', 'decrease discriminability classification', 'dependence new visualization', 'detect playing cards', 'detecting circles edge', 'detection circles require', 'detection geometric features', 'detects rectangular shapes', 'direction shape retrieval', 'discriminability classification task', 'discriminability distractor task', 'discriminability task simultaneously', 'distinguish trend dependence', 'distributed algorithm minimum', 'edges patterns images', 'emph learning pdes', 'existing 3d motion', 'fast linearized adm', 'feature based shape', 'feature detectors descriptors', 'fingertip detection techniques', 'flow dual min', 'flow manifolds ofms', 'flow minimum cut', 'formulation max flow', 'generalize search heuristics', 'gesture artificial neural', 'graph partitioned regions', 'heuristics derived abstractions', 'hierarchical search algorithm', 'high discriminability task', 'hough transform techniques', 'image articulation manifold', 'image classification benchmarks', 'image retrieval', 'image tests circles', 'improve feature detection', 'inference problems ai', 'large sparse problems', 'learn pdes', 'learning pde based', 'learning pdes real', 'learnt pdes solve', 'lmr rank minimization', 'local image descriptors', 'local image features', 'local pictorial structures', 'localization texture recognition', 'low discriminability distractor', 'low rank matrix', 'low rank representation', 'matrix estimation topic', 'matrix recovery lmr', 'matrix recovery nuclear', 'matrix sparse signal', 'max flow algorithms', 'max flow ccmf', 'maximum flow dual', 'method subspace clustering', 'minimum cut algorithms', 'minimum cut problem', 'models understand compression', 'motion tracking 3d', 'motion tracking needs', 'multiple component learning', 'multiple component matching', 'multiscale dictionaries extend', 'multiscale geometric decompositions', 'multiscale multi orientation', 'novel distributed algorithm', 'objectivity compression principle', 'observed features really', 'optical flow fields', 'optical flow images', 'optical flow manifolds', 'orientation bases dictionaries', 'oriented multiscale dictionaries', 'partitioned regions algorithm', 'parts based scene', 'parts sparse pictorial', 'person identification considered', 'person identification consists', 'person identification problem', 'person identification technique', 'purposely decrease discriminability', 'rank card image', 'rank cards matching', 'rank estimated matrix', 'rank matrix estimation', 'rank matrix large', 'rank matrix recovery', 'rank representation lrr', 'recognizing individual observed', 'representation matrix numerical', 'rigor objectivity compression', 'robust feature detection', 'robust low rank', 'rotation oriented multiscale', 'scene models', 'scene understanding', 'scheme detecting circles', 'semantic pixel labeling', 'sensing matrix sparse', 'shape feature detectors', 'shape retrieval algorithms', 'shape retrieval shrec', 'significance trends straightforward', 'sizer useful statistical', 'smoothing methods sizer', 'solve different vision', 'space optical flow', 'sparse pictorial structures', 'sparse signal recovery', 'subspace clustering wide', 'svd representation technique', 'techniques acquiring gesture', 'techniques detection circles', 'track screen 3d', 'tracking 3d motion', 'trend dependence new', 'underlying low rank', 'un ...
#
# --- Keywords for 2012 (226 total) ---
# ['2d photo object', '3d motion tracking', '3d pose known', '3d pose object', '3d reconstruction building', '3d reconstruction emerging', 'algorithmic graph theory', 'approach texture datasets', 'approach texture modeling', 'approaches identifying clusters', 'assessing value 3d', 'associative hierarchical network', 'associative markov networks', 'asymptotic minimax separation', 'automatic quantification ellipse', 'based topic models', 'body image gait', 'boundaries soft segmentation', 'boundary detection essential', 'cameras boundaries soft', 'captured topic mixing', 'cells images', 'cells splitting contour', 'classification space curves', 'classify scene mining', 'collaborative filtering', 'complicated topic models', 'component pursuit pcp', 'computer interaction hci', 'concept recognition tasks', 'constant curvatures suggest', 'contour processing', 'contour touching cells', 'contourlet transform feature', 'control mouse tasks', 'convolutional winner neurons', 'create 3d visualizations', 'curvature clustering uses', 'curve evolution used', 'curve evolution validates', 'curve evolutions based', 'curve evolutions establish', 'curve registration precisely', 'curves affine transformations', 'curves constant curvatures', 'data mixtures manifolds', 'data subspace segmentation', 'decomposition models', 'decomposition sample images', 'design product personalized', 'detection neutral pose', 'dimensionality reduction technique', 'discovering overlapping clusters', 'discrete energy minimization', 'efficiently captured topic', 'ellipse like cells', 'em algorithm', 'energy coarsening', 'energy minimization ubiquitous', 'estimating pose head', 'estimating projection features', 'existing topic modeling', 'face recognition performance', 'face recognition systems', 'feature extraction contourlet', 'fit curve registration', 'framework subspace clustering', 'gender recognition computer', 'gender recognition real', 'general curve evolutions', 'generative decomposition model', 'gesture recognition control', 'goodness fit curve', 'graph algorithms problems', 'graph clustering fundamental', 'graph clustering introduced', 'ground soft segmentation', 'handwritten digits traffic', 'head pose estimation', 'heuristics graph clustering', 'human computer interaction', 'human gender recognition', 'identifying 3d pose', 'identifying clusters network', 'identifying scene mining', 'image gabor features', 'image mining scenes', 'image segmentation based', 'image segmentation gesture', 'images occlusion boundaries', 'imaging anatomical modeling', 'implementation generative decomposition', 'improve robustness gender', 'independent component analysis', 'inner point tracking', 'interactive techniques personalized', 'invariants allowing detection', 'iterative techniques subspaces', 'kernel learning mkl', 'kernel svm sparse', 'known curve evolution', 'known robust principal', 'large number topics', 'lasso framework applications', 'latent dirichlet allocation', 'leaf texture analysis', 'linearly data subspace', 'low rank approximation', 'low rank matrix', 'manifold modeling increasingly', 'markerless 3d motion', 'markov network higher', 'markov networks higher', 'markov networks widely', 'minimax separation rates', 'mixtures manifolds challenging', 'mnist handwriting benchmark', 'models dimensional shapes', 'motion tracking critical', 'motion tracking systems', 'motivated lasso framework', 'mouse devices software', 'multi manifold modeling', 'multiple kernel learning', 'multiscale principles efficiently', 'multiscale scheme energy', 'object class segmentation', 'object projection feature', 'object screen track', 'occlusion boundaries object', 'original curve evolution', 'overlapping clusters networks', 'personalized product design', 'photo annotation challenge', 'point tracking performed', 'popular multiscale methods', 'pose detection presented', 'pose known object', 'poses face estimate', 'position tracking', 'principal component analysis', 'principal component pursu ...
#
# --- Keywords for 2013 (216 total) ---
# ['3d recovery gaze', 'acknowledged face recognition', 'algorithms hidden cloud', 'alignment stability microshutters', 'animals analysis behaviour', 'approach behavioural genetics', 'approximated spectral relaxation', 'assisted segmentation method', 'based basic sparse', 'based dictionary learning', 'based face detection', 'based image registration', 'based image retrieval', 'basis behavioural phenotype', 'behavioural phenotype conversely', 'benchmark visual representations', 'bioinformatics introducing elegans', 'board extraction subtraction', 'botswana tropical savanna', 'bsbl sparse representation', 'calibrated natural images', 'capture process recording', 'case causal segmentation', 'causal segmentation subsequent', 'chess board extraction', 'chess board vertices', 'chess feature detector', 'classifiers computational efficiency', 'cloud algorithms applied', 'cloud computing computer', 'cloud computing offers', 'cloud configure algorithm', 'clustering collection unlabeled', 'clustering features image', 'coding laplacian sparse', 'coding manifold manifold', 'computer vision library', 'computer vision sparse', 'confirm multidimensional persistent', 'consistent pixels causal', 'constraints visual recognition', 'constructing matrix approximations', 'convex optimization', 'convolutional features auto', 'data points subspaces', 'derivatives geodesic', 'detecting geometric shapes', 'detection recognition important', 'dictionaries patch based', 'dictionary learning key', 'dictionary learning methods', 'dictionary learning scheme', 'discrete geodesic calculus', 'discrete geodesics associated', 'discretization geodesic calculus', 'discriminative sparse coding', 'dynamic object detection', 'effective learning representations', 'efficient video segmentation', 'embedded applications image', 'exact principal geodesic', 'extended video segmentation', 'eye tracking', 'face based identification', 'face detection difficult', 'face detection recognition', 'face recognition image', 'features spatial pooling', 'features trained convolutional', 'formalize general recognition', 'fpga platform', 'gaze pointer human', 'genes involved neural', 'geodesic analysis pga', 'geodesics associated discrete', 'geodesics using numerical', 'graph sparse coding', 'hand crafted descriptors', 'hardware based', 'hardware implemented', 'high level representations', 'human cone photoreceptors', 'image based face', 'image database', 'image registration algorithms', 'image registration alignment', 'image retrieval cbir', 'image segmentation', 'image video processing', 'images cloud', 'imageval nohis search', 'isolate behavioural mutants', 'kernel methods nystrom', 'laplacian sparse coding', 'learning invariant representations', 'learning representations evaluation', 'learning structured', 'linear classifier overall', 'linear classifiers computational', 'localization chess board', 'low level representations', 'low rank matrices', 'low rank modeling', 'luispedro mahotas python', 'mahotas computer vision', 'mahotas python package', 'manifold learning discriminative', 'mapping monitoring human', 'matrix approximation common', 'matrix approximation model', 'matrix approximations partially', 'matrix low rank', 'method searching images', 'methods nystrom sampling', 'microsoft kinect', 'model assisted segmentation', 'modern computer vision', 'motion capture process', 'multidimensional persistence proved', 'multidimensional persistent homology', 'named sparse subspace', 'network localization squares', 'neural representation visual', 'new matrix approximation', 'new object detection', 'nohis search based', 'noisy measurements numerical', 'noisy measurements subset', 'novel dictionary learning', 'object classification tasks', 'object detection recognition', 'object tracking', 'outlier aware pca', 'outlier matrix robustification', 'particular discrete geodesics', 'patch based dictionary', 'persistent homology appropriate', 'persistent homology initially', 'photoreceptors pixel val ...
#
# --- Keywords for 2014 (226 total) ---
# ['ability lip read', 'action recognition', 'activity recognition', 'agglomerative algorithms', 'agglomerative clustering algorithms', 'algorithm agglomerative clustering', 'algorithm fast circle', 'algorithm faster achieves', 'algorithm grading potatoes', 'algorithm local message', 'algorithm mobile devices', 'appearances varying viewpoint', 'approximate quadratic assignment', 'assignment algorithm faq', 'assignment problems qaps', 'automatically detect face', 'average variational splines', 'based gpgpu processing', 'biologically plausible receptive', 'cameras map linear', 'circle detection digital', 'circle detection method', 'classic agglomerative clustering', 'classification', 'clustering agglomerative clustering', 'clustering algorithms robust', 'cnn feature', 'color potato ratio', 'combinatorial characterization optima', 'combines discriminative submodular', 'common image descriptors', 'computer interaction hci', 'computer vision interaction', 'computing squared curvature', 'conventional multiview reconstruction', 'convex program semidefinite', 'coordinates points rigid', 'covers key cryptographic', 'cryptographic primitives demonstrated', 'curvature based integral', 'curvature received', 'customizable vectorization raster', 'data clustering agglomerative', 'databases infrared facial', 'deep functions using', 'deep models', 'deep nets achieve', 'demonstrated usability digital', 'detect face image', 'detecting leaf damage', 'digital cryptography physical', 'digital cryptography real', 'dirichlet allocation lda', 'discriminative submodular cover', 'downsampling constraint optimal', 'efficient customizable vectorization', 'efficient svm alleviating', 'examples imaging opaque', 'explaining receptive field', 'face recognition able', 'face recognition biometric', 'face recognition presents', 'face recognition used', 'fast circle detector', 'features analysis footages', 'features multilabel annotation', 'finger tracking used', 'footage aerial view', 'footage approach', 'formulation relaxed convex', 'frames wavelets compact', 'fuzzy means segmentation', 'gpu heterogeneous implementation', 'graphs qap np', 'human computer interaction', 'human visual hierarchical', 'ica sparse coding', 'image annotation important', 'image descriptors computational', 'image face recognition', 'image segmentation challenging', 'images based catmull', 'imaging opaque objects', 'infrared facial images', 'infrared ir imaging', 'inspired sparse subspace', 'integral geometry model', 'integration digital cryptography', 'iteratively approximates energies', 'kernel learning adapts', 'kernel selection demonstrate', 'latent dirichlet allocation', 'leaf damage detection', 'learn deep functions', 'learned deep nets', 'learning localize objects', 'learning max product', 'learns visual features', 'length based regularization', 'linear color measurements', 'linear scene colors', 'linear submodular approximations', 'lip reading automating', 'lip reading used', 'local optimization methods', 'localize objects minimal', 'localized frames wavelets', 'low rank matrices', 'low rank matrix', 'low rank modeling', 'low rank tensor', 'machine learning max', 'map linear color', 'map pedestrian surveillance', 'mapped digital photograph', 'matching sets face', 'matching subspaces computing', 'matrix completion applied', 'matrix recovery convex', 'max product algorithm', 'mechanisms finger tracking', 'message passing algorithms', 'methods detecting leaf', 'mobile devices computationally', 'mobile gpgpu general', 'model learns visual', 'multi subspace representation', 'multilabel annotation features', 'multilabel image annotation', 'multilabel tagging', 'multiview footage', 'multiview reconstruction technique', 'nets learn deep', 'new tensor recovery', 'object recognition', 'object tracking', 'objects minimal supervision', 'occlusion resolve image', 'passing algorithms represent', 'pedestrian surveillance footage', 'photograph probability distribution', 'pixel tone mapped', 'pixel ...
#
# --- Keywords for 2015 (236 total) ---
# ['activity recognition', 'adaptive decision fusion', 'adaptive subspace tracking', 'additive occlusion generative', 'affinity measure clusters', 'agglomerative algorithm clustering', 'algorithm learn mixture', 'amplitude generalized pupil', 'appealing generative models', 'approximation blurring operator', 'attributes joint feature', 'author topic models', 'based caption syntax', 'based object matching', 'based sparse approximation', 'based topic models', 'based wildfire detection', 'better visual descriptor', 'bilateral filter exploiting', 'bilateral filter realized', 'bilateral filter requires', 'bilateral filtering using', 'blurring operator wavelet', 'bounds separation distance', 'bregman divergences clustering', 'bregman divergences essentially', 'bregman divergences good', 'bregman divergences originally', 'bregman divergences second', 'broad range segmentation', 'camera location estimation', 'caption syntax statistics', 'challenging computer vision', 'challenging generative models', 'character recognition hccr', 'chinese character recognition', 'classification retrieval performance', 'clustering high dimensional', 'clustering object matching', 'cnn features', 'cognition information compression', 'compact binary encoding', 'compact descriptor achieves', 'computational aspects estimators', 'computer vision task', 'computer vision theory', 'consider simultaneously matching', 'convnet', 'convolutional network produce', 'convolutional networks widely', 'convolutional neural networks', 'cutting plane algorithms', 'decision combined algorithm', 'decision fusion eadf', 'decision fusion method', 'deep architecture', 'deep belief networks', 'deep cnns', 'deep convolutional', 'deep learning', 'deep neural', 'demonstrate challenging generative', 'derivative compressed sensing', 'dictionary learning sparse', 'distributed learning address', 'distributed learning large', 'divergences good clustering', 'domain adaptation', 'drosophila tracking comparable', 'efficient distributed learning', 'efficient tracking', 'em algorithm learn', 'estimators upper bounds', 'face detection', 'facial landmark points', 'facial landmarks real', 'factorize tensors noise', 'factors marginalization constraint', 'fast bilateral filtering', 'features conformal divergences', 'flies distinct walking', 'fragments natural vision', 'fusion method based', 'garment attribute classification', 'garment attributes furthermore', 'garment attributes joint', 'gaussian bilateral filter', 'general matching', 'generalized pupil function', 'generate descriptive sentences', 'generative models computer', 'generative models promised', 'gliding behavioral statistics', 'gradient gpf phase', 'graph based agglomerative', 'graph cuts based', 'graph matching', 'grassmannian robust adaptive', 'grasta grassmannian robust', 'head pose', 'high dimensional features', 'homoscedastic heteroscedastic noise', 'homoscedastic heteroscedastic settings', 'human action recognition', 'human parts image', 'human pose estimation', 'ill posed operator', 'image classification content', 'image clustering object', 'image descriptors', 'image feature correspondences', 'image reconstructions', 'image segmentation case', 'image using phrases', 'implementation bilateral filter', 'implementations computing convolutions', 'individual labels learned', 'instance label prediction', 'intrinsic image decomposition', 'inverse problems numerical', 'joint feature representation', 'kernel bilateral filter', 'known tensor factorizations', 'label prediction results', 'label proportions training', 'landmarks real time', 'large convolutional network', 'large dimension features', 'latent dirichlet allocation', 'learn mixture bernoulli', 'learn mixture gaussian', 'learning algorithms privacy', 'learning compact binary', 'learning label proportions', 'learning mixture high', 'learning sparse coding', 'linear programming relaxations', 'localization salient facial', 'locations noisy pairwise', 'low rank representation', 'map mrf ...
#
# --- Keywords for 2016 (232 total) ---
# ['3d reconstruction', '3d surface models', 'able learn rotation', 'action images', 'actions annotated likely', 'activity understanding anticipating', 'adversarial', 'aerial image understanding', 'aerial images', 'ambient intelligence', 'annotating observed social', 'anticipating explaining action', 'applying edge detectors', 'approximate nearest neighbor', 'art object detection', 'attention', 'autonomous measurement', 'background subtraction', 'binary descriptors', 'binary transfer learning', 'biological vision governed', 'biovie physical phenomenon', 'biovision phenomenon basis', 'blind image deblurring', 'bv finsler metric', 'bv geodesics', 'caliper tape measure', 'classification approaches achieves', 'clustering iteration', 'clustering nonlinearly separable', 'cnn models', 'computer vision convolutional', 'computer vision object', 'context aerial image', 'convex priors difficult', 'convex relaxations', 'convnets', 'convolutional neural networks', 'correspondences iterative methods', 'crowdsourcing', 'curves finsler metric', 'cut algorithm image', 'cut image segmentation', 'cut max flow', 'cut maximum flow', 'deblurring discriminative approaches', 'deep architecture', 'deep cnn architectures', 'deep convolutional neural', 'deep learning models', 'deep recurrent', 'denoising image deblurring', 'detect various fashion', 'detection fashion items', 'detection important challenges', 'detector depends domain', 'diameter grapevines based', 'diameter variable agricultural', 'discretization minimal geodesic', 'discretizing laplace beltrami', 'discriminative prediction', 'domain image restoration', 'domain image video', 'dual optimization approach', 'edge detection images', 'edge detection method', 'edge detection vital', 'edge preserving filtering', 'edges image', 'efficiently target set', 'egocentric cameras', 'egocentric videos', 'electron microscopes', 'energy minimization techniques', 'face recognition', 'fashion item detection', 'fashion items consider', 'fashion items person', 'feature descriptors commonly', 'feature detectors', 'feature selection extraction', 'fruit trees production', 'fully convolutional networks', 'gaussian bilateral filter', 'gradient descent', 'high dimensional data', 'human action recognition', 'human activity understanding', 'human pose estimation', 'hypotheses feature dimensions', 'image deblurring discriminative', 'image deblurring proposed', 'image restoration tasks', 'image segmentationand edge', 'imagenet', 'instance learning', 'instance segmentation', 'joint variable selection', 'laws biovision phenomenon', 'learn rotation invariant', 'loose semidefinite relaxation', 'mapping slam', 'matrix completion', 'max flow algorithms', 'method discretizing laplace', 'method edge detection', 'method measurement trunk', 'methodology edge detection', 'methods semidefinite programming', 'minimal geodesic problem', 'minimization techniques stereo', 'minimize geodesic energy', 'minimizer weighted surrogate', 'minimum cut problem', 'model image restoration', 'mrf energy minimization', 'mrfs non convex', 'multiple object tracking', 'nearest neighbor search', 'networks cnns', 'networks rnn', 'neural networks cnn', 'noisy relative transformations', 'noisy transformations', 'non convex priors', 'normalized cut algorithm', 'normalized cut image', 'object detection important', 'object detectors usually', 'object localization', 'object proposals', 'object recognition tasks', 'object segmentation', 'observed social responses', 'opinions annotating observed', 'optical flow', 'optimization finds representatives', 'optimization function regularization', 'outperforming transfer learning', 'pairwise alignments', 'pairwise transformations transitively', 'pants shoes detection', 'pdes manifolds', 'pedestrian detection', 'performance deep', 'phenomenon time model', 'pixel level semantic', 'pooling joint normalization', 'popular feature selection', 'predicting agreement receptivity', 'prediction fruit trees', 'proposed phenomenon t ...
#
# --- Keywords for 2017 (226 total) ---
# ['3d convolutional neural', '3d human pose', '3d point cloud', '3d reconstruction', 'action prediction', 'action recognition benchmarks', 'activity recognition', 'adaptation deep models', 'advances deep learning', 'aesthetic score distribution', 'algorithms minimization useful', 'algorithms present cloudcv', 'appearance based gaze', 'approximate label assignment', 'approximated simpler piecewise', 'approximation performance representations', 'architectural compiler optimizations', 'architecture deep', 'arise video inpainting', 'attention network', 'automatic video inpainting', 'based gaze estimation', 'baseline precision network', 'beehive hardware software', 'binary weight cnns', 'blind deblurring', 'bundle adjustment', 'cloudcv comprehensive provide', 'cnn architectures', 'cnn compression', 'cnn models', 'cnn trained', 'coco datasets', 'compact linear programs', 'computer vision research', 'computer vision tasks', 'conditional generative adversarial', 'contour based corner', 'convolutional layers', 'convolutional networks', 'convolutional neural networks', 'core similarity search', 'corner detector', 'crowd counting', 'crowd disasters', 'crowd surveillance computer', 'data learning', 'deep architectures', 'deep cnns trained', 'deep convolution neural', 'deep convolutional neural', 'deep embedding', 'deep features', 'deep image', 'deep learning adapting', 'deep learning dl', 'deep learning important', 'deep learning methods', 'deep metric learning', 'deep networks', 'deep neural networks', 'deep residual networks', 'deeper networks', 'detection based deep', 'discriminative training', 'distributed computer vision', 'domain adaptation algorithms', 'domain adaptation datasets', 'efficient algorithms minimization', 'efficient dnns', 'efficient learning scheme', 'einstein rings arcs', 'emotion recognition', 'existing saliency detection', 'eye region models', 'eye shape registration', 'face alignment', 'face datasets', 'face detection', 'facial feature', 'facial landmark detection', 'faster cnn', 'foveated object detector', 'fully convolutional network', 'function interpolation routines', 'functions avoid overfitting', 'gaze estimation recent', 'gaze estimation wild', 'generative adversarial networks', 'generic video inpainting', 'graphics processing', 'grasp detection', 'head pose estimation', 'hough transform', 'human action recognition', 'human pose estimation', 'image fusion', 'image matching', 'image segmentation', 'image synthesis', 'image video inpainting', 'imagenet classification', 'improvements pedestrian detection', 'inception network', 'inference labeling tasks', 'inference learning', 'interpolation routines present', 'label image classification', 'learning large scale', 'light image enhancement', 'linear programming lp', 'linear programming relaxation', 'low rank matrix', 'lp relaxation equivalent', 'lp relaxation piecewise', 'map inference problem', 'massive visual data', 'material recognition', 'matrix factorization', 'methods adaptation deep', 'methods crowd', 'minimization useful subclass', 'modern object detectors', 'motion capture', 'motion estimation', 'multi object tracking', 'multilayer perceptron', 'network cnn', 'network weights deep', 'networks cnns', 'networks dcnns', 'neural style transfer', 'normal integration focus', 'novel efficient learning', 'object detection classifiers', 'object detector fod', 'object detectors computer', 'object pose estimation', 'object recognition', 'object reconstruction', 'optical flow', 'optimal solutions inference', 'pedestrian attribute recognition', 'pedestrian detection based', 'pedestrian detection open', 'pedestrian detection popular', 'piecewise linear approximations', 'piecewise polynomial representations', 'point cloud classification', 'pose regression', 'precision activation maps', 'prediction using deep', 'present cloudcv comprehensive', 'problem map inference', 'programming lp relaxation', 'programming relaxation map', 'project beehive hardware', 'propose pedestri ...
#
# --- Keywords for 2018 (213 total) ---
# ['3d face', '3d point clouds', '3d pose estimation', '3d shape classification', '3d shape recognition', '3d shape representation', 'action classification', 'action video', 'active learning', 'adversarial examples', 'adversarial machine learning', 'adversarial nets gans', 'adversarial networks gans', 'adversarial perturbations', 'adversarial robustness', 'aerial image labeling', 'algorithms consensus maximization', 'architectures deep learning', 'attention model', 'automatic differentiation tools', 'black box adversarial', 'brain computer interfaces', 'brain tumor segmentation', 'camera relocalization', 'cameras', 'cancer cell line', 'capsule networks', 'classification human emotions', 'cnn accelerators', 'cnn architectures', 'cnn based', 'cnn models', 'cnn significantly', 'compressed sensing', 'computer vision pipelines', 'conditional generative adversarial', 'convolutional filters retina', 'convolutional network', 'convolutional neural networks', 'correspondence images', 'count objects', 'data augmentation training', 'database facial expression', 'datasets human action', 'deep alignment network', 'deep architectures', 'deep cnns', 'deep convolutional neural', 'deep domain adaptation', 'deep features', 'deep generative', 'deep hashing methods', 'deep learning algorithms', 'deep learning approaches', 'deep learning computer', 'deep learning dl', 'deep learning methods', 'deep learning models', 'deep learning recently', 'deep learning reinforcement', 'deep learning rgb', 'deep learning robotics', 'deep learning widely', 'deep metric learning', 'deep model', 'deep neural networks', 'deep reinforcement learning', 'deep residual', 'deep transfer learning', 'denoising autoencoder', 'depth completion', 'depth estimation task', 'detecting tracking', 'discovery convolutional filters', 'domain adaptation methods', 'driver attention', 'emotion recognition solve', 'existing deep learning', 'expression recognition systems', 'extreme learning', 'face analysis', 'face model', 'face verification', 'facial attribute classification', 'facial attributes', 'facial expression recognition', 'facial landmark detection', 'facial landmarks classification', 'feature fusion', 'feature selection', 'features point cloud', 'food images', 'gan based', 'generative adversarial nets', 'generative adversarial networks', 'generative models', 'graph kernels', 'graphics processing', 'hand gestures', 'handwritten', 'hidden layer convolutional', 'human action recognition', 'human activity recognition', 'image classification', 'image denoising high', 'image depth prediction', 'image image translation', 'image matching', 'image video compression', 'learning deep', 'learning reinforcement learning', 'learning visual features', 'local feature descriptors', 'lossy image compression', 'low rank matrices', 'lung nodule detection', 'machine learning extracting', 'machine translation', 'manifold learning', 'mapping slam', 'matrix completion', 'monocular depth estimation', 'motion blur', 'multi task learning', 'natural vision', 'nearest neighbor', 'network cnn', 'networks cnns', 'networks dcnns', 'neural network architectures', 'neural networks cnn', 'neural networks dnns', 'neural networks rnns', 'new deep learning', 'object classification', 'object counting important', 'object detection networks', 'object detection pipelines', 'object detectors', 'object pose estimation', 'object recognition datasets', 'object tracking important', 'optical flow estimation', 'optimization deep', 'pedestrian detection', 'performance cnn', 'person identification', 'pixel wise classification', 'point detection', 'predicting action', 'quantized neural networks', 'question answering vqa', 'recurrent neural networks', 'reflections images', 'reinforcement learning rl', 'remote sensing imagery', 'remove rain images', 'residual networks', 'results shot learning', 'robust tracking', 'saliency detection', 'saliency map estimation', 'saliency maps', 'saliency prediction', 'salient object detection', 'sa ...
#
# --- Keywords for 2019 (216 total) ---
# ['3d correspondences', '3d face', '3d object models', '3d point clouds', '3d semantic', 'action detection', 'action recognition videos', 'advances deep learning', 'adversarial attacks', 'adversarial examples computer', 'adversarial loss', 'adversarial network gan', 'adversarial networks gans', 'adversarial perturbation', 'adversarial samples', 'adversarial training', 'attacks adversarial', 'attention based', 'attention map', 'attention network', 'audio classification', 'autonomous cars', 'autonomous driving', 'aware attention', 'background subtraction methods', 'camera pose estimation', 'camera pose regression', 'capsule network', 'chest radiographs', 'classification video', 'cnn architectures', 'cnn based object', 'cnn models', 'computer vision community', 'computer vision cv', 'computer vision tasks', 'conditional generative adversarial', 'convnets', 'convolutional networks', 'convolutional neural networks', 'crafted adversarial', 'data augmentation', 'deep architectures', 'deep cnn', 'deep convolutional neural', 'deep domain adaptation', 'deep features', 'deep generative', 'deep learning algorithms', 'deep learning dl', 'deep learning methods', 'deep learning models', 'deep learning recommender', 'deep metric learning', 'deep network architectures', 'deep networks face', 'deep neural networks', 'deep reinforcement learning', 'dense 3d reconstruction', 'deploying face recognition', 'depth estimation networks', 'depth map', 'detection 360', 'dnn architectures', 'domain adaptation da', 'domain adaptation methods', 'domain adversarial neural', 'domain shift training', 'domains training', 'edge detection', 'emotion recognition', 'event cameras', 'eye tracking', 'face alignment', 'face datasets', 'face detector', 'face recognition mobile', 'faster cnn', 'foreground detection', 'gan generated images', 'gan trained generate', 'gan training', 'gans gans', 'generative adversarial networks', 'gestures', 'graph convolutional network', 'graph matching', 'hand gesture recognition', 'hand pose estimation', 'human action recognition', 'human pose estimation', 'image captioning model', 'image classification', 'image deblurring', 'image features', 'image image translation', 'image segmentation', 'image transformations', 'imagenet classification', 'imagenet dataset', 'imitation learning', 'improve tracking', 'inference network', 'low rank sparse', 'mask cnn', 'matrix completion', 'matrix factorization', 'meta learning', 'models vulnerable adversarial', 'monocular depth estimation', 'motion prediction', 'multi person pose', 'multiple object tracking', 'multiview ideal', 'network cnn', 'networks cnns', 'networks dnns', 'networks residual', 'neural architecture search', 'neural networks cnn', 'new adversarial attack', 'object detection computer', 'object detection model', 'object detectors', 'object representations', 'object segmentation', 'optical flow', 'panoptic segmentation', 'pedestrian detection', 'pedestrian tracking', 'perceptual image quality', 'person pose estimation', 'person reid', 'pixel detectors', 'point cloud registration', 'pose estimation fundamental', 'pose estimation important', 'pose estimation scene', 'predict 3d', 'present quantum algorithm', 'principal component pursuit', 'privacy', 'programmable cnn accelerator', 'quantum computers', 'quantum computing', 'rainy images', 'reasoning images', 'receptive fields', 'recognition challenge lpirc', 'reconstructing 3d', 'recurrent neural network', 'registration 3d point', 'relative pose estimation', 'remote sensing', 'representing 3d shape', 'residual networks', 'rigid registration', 'robot vision', 'robust principal component', 'saliency detection', 'saliency models', 'saliency prediction', 'satellite imagery', 'scene classification', 'scene flow estimation', 'scene text recognition', 'scene understanding', 'segmentation masks', 'self supervised learning', 'self supervised representation', 'self supervised visual', 'semantic segmentation autonomous', 'semantic segmentation networ ...
#
# --- Keywords for 2020 (216 total) ---
# ['3d detection', '3d hand pose', '3d human', '3d object reconstruction', '3d point clouds', '3d semantic', '3d shapes', '6d pose estimation', 'action classification', 'action detection', 'action localization', 'active learning', 'activity recognition', 'adversarial attacks', 'adversarial defense', 'adversarial images', 'adversarial networks gans', 'adversarial patches', 'adversarial perturbations fool', 'adversarial samples', 'adversarial training', 'aerial vehicles uavs', 'affect prediction', 'approaches using deep', 'attention layers', 'attention network', 'augmented reality', 'based action recognition', 'batch normalization bn', 'bayesian deep learning', 'capsule networks', 'change detection', 'chaotic phase', 'character recognition ocr', 'classification image retrieval', 'cloud semantic segmentation', 'cnn architectures', 'cnn models', 'cnn rnn', 'cnn training', 'computer vision datasets', 'computer vision deep', 'conditional generative adversarial', 'continual learning', 'contrastive learning', 'convolutional architectures', 'convolutional filters', 'convolutional layers', 'convolutional neural networks', 'crowd counting', 'data augmentation', 'deep architectures', 'deep cnn', 'deep convolutional', 'deep generative models', 'deep image prior', 'deep learning algorithms', 'deep learning approaches', 'deep learning architectures', 'deep learning computer', 'deep learning dl', 'deep learning models', 'deep models', 'deep neural networks', 'deep reinforcement learning', 'deep video architectures', 'depth estimation semantic', 'depth maps', 'detecting adversarial', 'detection tracking', 'dimensionality reduction techniques', 'driver attention', 'edge computing', 'edge detection', 'effective cnn', 'emotion recognition based', 'encoder decoder networks', 'evaluating performance gans', 'event cameras bio', 'expression recognition fer', 'face recognition', 'facial action units', 'facial expression recognition', 'feature descriptor', 'feature detectors', 'feature fusion', 'feature pyramid network', 'federated learning', 'finds adversarial', 'gait recognition', 'gan architectures', 'gan generated images', 'generate adversarial', 'generative adversarial networks', 'gesture recognition', 'grained visual categorization', 'graph convolutional network', 'graph convolutional neural', 'graph neural networks', 'hand pose estimation', 'hough transform', 'human action recognition', 'human actions videos', 'image captioning', 'image compression', 'image dehazing', 'image denoising', 'image features', 'image restoration', 'image segmentation', 'image super resolution', 'imagenet classification', 'imagenet pre training', 'images gan basis', 'instance learning', 'instance segmentation', 'learning 3d', 'learning computer vision', 'learning deep', 'learning graph convolution', 'learns low dimensional', 'light image enhancement', 'low light image', 'low rank matrix', 'mask cnn', 'meta learning shot', 'metric learning', 'models trained', 'models vulnerable adversarial', 'monocular depth estimation', 'multi task learning', 'multiple object tracking', 'multitask learning', 'network cnn', 'network gan', 'networks cnns', 'networks dnns', 'networks gans increasingly', 'networks rnns', 'neural architecture search', 'neural network compression', 'neural networks cnn', 'neuroscore gan generated', 'object 6d pose', 'object detection semantic', 'object detectors widely', 'object grasping', 'object pose estimation', 'object tracking mot', 'optical flow estimation', 'panoptic segmentation', 'pedestrian tracking', 'performance deep', 'performance gans directly', 'person identification', 'point cloud fundamental', 'point cloud segmentation', 'point cloud semantic', 'pose estimation monocular', 'power deep learning', 'pre trained imagenet', 'quality images gan', 'quality stylized images', 'rank matrix approximation', 'reality vr', 'recognition deep learning', 'recognition using deep', 'recurrent convolutional neural', 'recurrent neural networks', 'remote sensing',  ...
#
# --- Keywords for 2021 (210 total) ---
# ['3d cnns', '3d face reconstruction', '3d hand pose', '3d point clouds', '3d pose estimation', '3d reconstruction', 'accuracy imagenet', 'activity recognition har', 'adversarial attacks deep', 'adversarial examples', 'adversarial networks gans', 'adversarial robustness', 'adversarial training', 'aerial vehicle', 'attacks deep learning', 'attention layers', 'attention maps', 'attention models', 'attention modules', 'attention network', 'autoencoders', 'automatic speech', 'autonomous driving', 'backpropagation', 'binary classifier', 'camera calibration', 'camera poses 3d', 'catastrophic forgetting', 'character recognition', 'classifiers', 'cnn architectures', 'cnn based classification', 'cnn classify', 'cnn models', 'cnn transformer', 'cnns achieve', 'cnns transformers', 'coco dataset', 'coco instance segmentation', 'computer vision attention', 'computer vision cv', 'computer vision tasks', 'contrastive self supervised', 'convnets', 'convolutional architectures', 'convolutional neural networks', 'cropping', 'cross modal retrieval', 'data augmentation', 'datasets computer vision', 'deep architecture', 'deep clustering', 'deep convolutional neural', 'deep features', 'deep generative', 'deep learning dl', 'deep learning medical', 'deep learning models', 'deep metric learning', 'deep models', 'deep neural networks', 'deep reinforcement learning', 'deep transfer', 'deeper networks', 'defect detection', 'depth image', 'depth maps', 'detecting small objects', 'dnn architecture', 'domain adaptation methods', 'edge cloud', 'edges noisy images', 'event cameras', 'existing cnns', 'explainable ai', 'facial expression recognition', 'faint edge detection', 'faster cnn', 'feature descriptors', 'feature fusion', 'federated learning', 'fisheye cameras commonly', 'fisheye images', 'gan architectures', 'gan variants', 'generative adversarial networks', 'gestures', 'graph autoencoder', 'graph convolutional networks', 'graph matching', 'graph neural networks', 'human action recognition', 'human activity recognition', 'human detection', 'human pose estimation', 'hyperspectral image', 'image captioning', 'image classification tasks', 'image image translation', 'image inpainting', 'image quality assessment', 'image segmentation', 'image super resolution', 'imagenet classification', 'imagenet models', 'incremental learning', 'knowledge distillation', 'learn discriminative features', 'learned image compression', 'learning 3d', 'learning deep', 'learning optical flow', 'local attention', 'low light image', 'mask cnn', 'matrix completion', 'meta learning', 'models deep learning', 'models imagenet', 'models trained images', 'monocular depth estimation', 'multi object tracking', 'multi task learning', 'multimodal fusion', 'multiple object tracking', 'natural language processing', 'network cnn', 'networks cnns', 'neural architecture search', 'neural architectures', 'neural network architectures', 'object detection semantic', 'object detectors', 'object pose estimation', 'object recognition', 'object segmentation', 'object trackers', 'object tracking mot', 'optical flow estimation', 'overhead imagery datasets', 'panoptic segmentation', 'performance deep', 'person identification id', 'photometric stereo', 'pixel wise regression', 'point cloud processing', 'point cloud registration', 'pointnet', 'pre trained imagenet', 'pretrained imagenet', 'quantized neural networks', 'question answering vqa', 'rainy images', 'relative pose estimation', 'remote sensing', 'robustness adversarial', 'salient object detection', 'sar image', 'scene classification', 'scene graph generation', 'scene parsing', 'self attention module', 'self supervised learning', 'self supervised representation', 'semantic segmentation networks', 'semi supervised learning', 'shot action recognition', 'sign language recognition', 'single image super', 'single object tracking', 'softmax', 'sparse coding', 'spatial attention', 'spectral clustering affinity', 'spiking neural networks', 'state art deep', 's ...
#
# --- Keywords for 2022 (215 total) ---
# ['3d detection', '3d human pose', '3d object detection', '3d point cloud', '3d pose estimation', '6d pose estimation', 'accuracy imagenet', 'active learning', 'activity recognition har', 'advances deep learning', 'advances self supervised', 'adversarial attacks', 'adversarial examples', 'adversarial networks gans', 'adversarial patches', 'adversarial robustness deep', 'adversarial samples', 'adversarial training', 'adversarially robust', 'aerial images', 'aerial object detection', 'approximate nearest neighbor', 'articulated objects', 'attention based encoder', 'attention computer vision', 'attention layers', 'attention maps', 'attention models', 'backdoor attacks', 'catastrophic forgetting', 'cnn architectures', 'cnn backbone', 'cnn models', 'cnn transformer', 'cnns vision transformers', 'coco object detection', 'computer vision community', 'computer vision cv', 'computer vision datasets', 'computer vision deep', 'computer vision reinforcement', 'computer vision tasks', 'continual learning', 'contrastive learning', 'contrastive self supervised', 'convolutional layers', 'convolutional neural networks', 'crowd counting', 'data augmentation techniques', 'deep cnn', 'deep convolutional neural', 'deep features', 'deep generative models', 'deep learning computer', 'deep learning dl', 'deep learning methods', 'deep learning models', 'deep learning techniques', 'deep models', 'deep neural networks', 'deep reinforcement learning', 'detection adversarial', 'detection tracking', 'domain adaptation da', 'domain adaptation uda', 'edge computing', 'edge detection', 'efficient attention', 'efficient deep', 'embodied ai', 'equivariance neural networks', 'equivariant neural', 'event cameras', 'explainable artificial intelligence', 'fashion datasets', 'faster cnn', 'federated learning', 'fine grained recognition', 'forecasting', 'gait recognition', 'gaze estimation', 'generative adversarial networks', 'generic object detection', 'graph convolutional network', 'graph matching', 'graph neural networks', 'hand pose', 'human action recognition', 'human activity recognition', 'human pose estimation', 'illumination', 'image captioning', 'image classification tasks', 'image dehazing', 'image denoising', 'image image translation', 'image quality assessment', 'image retrieval', 'image super resolution', 'keyword spotting', 'knowledge distillation', 'lane detection', 'learned image compression', 'learning remote sensing', 'local attention', 'low light image', 'low rank tensor', 'machine learning ml', 'masked autoencoders', 'medical image analysis', 'medical image segmentation', 'medical imaging datasets', 'meta learning', 'model action recognition', 'model compression', 'monocular depth estimation', 'motion capture', 'motion prediction', 'multi label classification', 'multi layer perceptron', 'multi object tracking', 'multi task learning', 'multiple object tracking', 'network cnn', 'networks cnns', 'networks gnns', 'neural architecture search', 'neural network architectures', 'neural network video', 'neural networks dnns', 'nlp computer vision', 'novel deep learning', 'object detection tasks', 'object detectors', 'object pose estimation', 'object recognition', 'optical flow', 'perceptual image quality', 'performance deep', 'person identification id', 'point cloud analysis', 'point cloud classification', 'point cloud registration', 'pre trained models', 'privacy preserving', 'quantum neural networks', 'rank tensor completion', 'recent self supervised', 'recognition ocr', 'reconstructing 3d', 'regularization', 'relative pose estimation', 'residual networks resnets', 'saliency maps', 'salient object detection', 'scene flow', 'scene graph', 'security deep learning', 'self attention module', 'self supervised learning', 'self supervised models', 'self supervised pretraining', 'self supervised representation', 'semantic segmentation', 'semi supervised learning', 'shot image classification', 'sign language', 'single image super', 'single object tracking', 'spik ...

# %%
# Use set.union() to efficiently combine all keyword sets from the dictionary.
# The '*' unpacks the dictionary's values (which are sets of keywords) into arguments
# for the union function.
final_unique_keywords = set.union(*yearly_final_keywords.values())

# Convert the final set to a sorted list with the requested name
cvkeywords20102022normalized = sorted(list(final_unique_keywords))

# Print the results to confirm
print(f"Created final combined list named 'cvkeywords20102022normalized' with {len(cvkeywords20102022normalized)} unique keywords.")
print("\nSample of the final list:")
print(cvkeywords20102022normalized[:])
# Out:
# Created final combined list named 'cvkeywords20102022normalized' with 2266 unique keywords.
#
# Sample of the final list:
# ['2d photo object', '3d cnns', '3d convolutional neural', '3d correspondences', '3d detection', '3d face', '3d face reconstruction', '3d hand pose', '3d human', '3d human pose', '3d model natural', '3d motion tracking', '3d object detection', '3d object models', '3d object reconstruction', '3d point cloud', '3d point clouds', '3d pose estimation', '3d pose known', '3d pose object', '3d reconstruction', '3d reconstruction building', '3d reconstruction emerging', '3d recovery gaze', '3d semantic', '3d shape classification', '3d shape recognition', '3d shape representation', '3d shapes', '3d surface models', '6d pose estimation', 'ability lip read', 'able learn rotation', 'abstractions generalization gives', 'accuracy imagenet', 'accurately detecting pedestrians', 'acknowledged face recognition', 'acquiring gesture artificial', 'action classification', 'action detection', 'action images', 'action localization', 'action prediction', 'action recognition', 'action recognition benchmarks', 'action recognition videos', 'action video', 'actions annotated likely', 'active learning', 'activity recognition', 'activity recognition har', 'activity understanding anticipating', 'adaptation deep models', 'adaptive decision fusion', 'adaptive subspace tracking', 'additive occlusion generative', 'advances deep learning', 'advances self supervised', 'adversarial', 'adversarial attacks', 'adversarial attacks deep', 'adversarial defense', 'adversarial examples', 'adversarial examples computer', 'adversarial images', 'adversarial loss', 'adversarial machine learning', 'adversarial nets gans', 'adversarial network gan', 'adversarial networks gans', 'adversarial patches', 'adversarial perturbation', 'adversarial perturbations', 'adversarial perturbations fool', 'adversarial robustness', 'adversarial robustness deep', 'adversarial samples', 'adversarial training', 'adversarially robust', 'aerial image labeling', 'aerial image understanding', 'aerial images', 'aerial object detection', 'aerial vehicle', 'aerial vehicles uavs', 'aesthetic score distribution', 'affect prediction', 'affinity measure clusters', 'agglomerative algorithm clustering', 'agglomerative algorithms', 'agglomerative clustering algorithms', 'algorithm agglomerative clustering', 'algorithm fast circle', 'algorithm faster achieves', 'algorithm grading potatoes', 'algorithm learn mixture', 'algorithm local message', 'algorithm minimum cut', 'algorithm mobile devices', 'algorithm searches', 'algorithm searching', 'algorithmic graph theory', 'algorithms consensus maximization', 'algorithms hidden cloud', 'algorithms minimization useful', 'algorithms present cloudcv', 'alignment point sets', 'alignment stability microshutters', 'alternative online boosting', 'ambient intelligence', 'amplitude generalized pupil', 'animals analysis behaviour', 'annotating observed social', 'anticipating explaining action', 'appealing generative models', 'appearance based gaze', 'appearances varying viewpoint', 'application computer vision', 'applying edge detectors', 'approach behavioural genetics', 'approach point detection', 'approach texture datasets', 'approach texture modeling', 'approaches identifying clusters', 'approaches using deep', 'approximate label assignment', 'approximate nearest neighbor', 'approximate quadratic assignment', 'approximate spectral analysis', 'approximated simpler piecewise', 'approximated spectral relaxation', 'approximation blurring operator', 'approximation performance representations', 'architectural compiler optimizations', 'architecture deep', 'architectures deep learning', 'arise video inpainting', 'art object detection', 'articulated object detection', 'articulated objects', 'assessing value 3d', 'assignment algorithm faq', 'assignment problems qaps', 'assisted segmentation method', 'associative hierarchical network', 'associative markov networks', 'asymmetric boosting methods', 'asymptotic minimax separation', 'attacks adversarial', 'attacks deep learning', 'attention' ...
